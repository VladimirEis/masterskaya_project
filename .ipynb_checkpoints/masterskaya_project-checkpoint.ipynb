# %% [markdown]
# <a id='start'></a>
# # Проект Мастерская №1

# %% [markdown]
# ## Цель проекта
# Отработать навыки работы с реальными данными.
# В качестве примера приведены данные о стартапах, функционировавших с 1980 по 2018 годы.
# Необходимо разработать модель машинного обучения при предсказания продолжения работы стартапа.
# Провести все необходимые работы с исходными датасетами и дать рекомендации создателям стартапов.

# %% [markdown]
# ### Задачи для 1 части проекта:
# * [Изучить и подготовить данные](#download)
# * [Провести предобработку данных](#preprocessing)
# * [Провести исследователький анализ данных](#research)
# * [Провести корреляционный анализ данных](#corr)
# * [Уменьшить число категориальных признаков в тренировочном датасете](#categories_train)
# * [Уменьшить число категориальных признаков в тестовом датасете](#categories_test)
#
# ### Задачи для 2 части проекта:
# * [Разработать модели для предсказания статуса стартапов](#models)

# %% [markdown]
# <a id='download'></a>
# ## [Загрузка данных](#start)

# %% [markdown]
# **Для корректной работы проекта были установлены:**
# * Обновление sklearn
# * Модуль shap
# * matplotlib версии 3.7.0

# %%
pip install -U scikit-learn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: julynter 0.4.2 has a non-standard dependency specifier jupyter-server<2requests,>=1.6. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of julynter or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install shap -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: julynter 0.4.2 has a non-standard dependency specifier jupyter-server<2requests,>=1.6. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of julynter or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
pip install matplotlib==3.7.0 -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: julynter 0.4.2 has a non-standard dependency specifier jupyter-server<2requests,>=1.6. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of julynter or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shap
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.impute import SimpleImputer
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    StandardScaler
)
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
# Задаем необходимые константы
RANDOM_STATE = 42

# %%
# Загружаем тренировочную выборку
startups_train = pd.read_csv(
    'datasets/kaggle_startups_train_28062024.csv'
)
# Просматриваем первичную информацию о датасете
startups_train.info()
# Просматриваем первые 5 строк датасета
startups_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   founded_at         52516 non-null  object
#  10  first_funding_at   52516 non-null  object
#  11  last_funding_at    52516 non-null  object
#  12  closed_at          4917 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.2+ MB
#                      name                          category_list  \
# ...

# %%
# Загружаем тестовую выборку
startups_test = pd.read_csv(
    'datasets/kaggle_startups_test_28062024.csv'
)
# Просматриваем первичную информацию о датасете
startups_test.info()
# Просматриваем первые 5 строк датасета
startups_test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      12534 non-null  object
#  2   funding_total_usd  10547 non-null  float64
#  3   country_code       11743 non-null  object
#  4   state_code         11430 non-null  object
#  5   region             11536 non-null  object
#  6   city               11538 non-null  object
#  7   funding_rounds     13125 non-null  int64
#  8   first_funding_at   13125 non-null  object
#  9   last_funding_at    13125 non-null  object
#  10  lifetime           13125 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.1+ MB
#                      name                   category_list  funding_total_usd  \
# 0              Crystalsol                Clean Technology          2819200.0
# ...

# %%
# Загружаем информацию о статусе стартапа
startups_status = pd.read_csv(
    'datasets/kaggle_startups_sample_submit_28062024.csv'
)
# Просматриваем первичную информацию о датасете
startups_status.info()
# Просматриваем первые 5 строк датасета
startups_status.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    13125 non-null  object
#  1   status  13125 non-null  object
# dtypes: object(2)
# memory usage: 205.2+ KB
#                      name     status
# 0              Crystalsol     closed
# 1        JBI Fish & Wings  operating
# 2                COINPLUS     closed
# 3  Imagine Communications     closed
# 4                   DNA13  operating

# %%
# Объединяем датасет с тестовыми данными с датасетом с входными признаками для дальнейшей работы
startups_test = startups_test.merge(
    startups_status, on='name'
)

# %% [markdown]
# **Можно заметить, что в тестовой выборке нет параметров стартапа 'founded_at' и 'closed_at'. В ней они заменены параметром lifetime который является количеством дней от старта до закрытия стартапа.**

# %%
# Переведем дату основания фирм в формат даты
startups_train['founded_at'] = pd.to_datetime(
    startups_train['founded_at'], format='%Y-%m-%d'
)
# Не закрытые фирмы не имеют даты закрытия, поэтоу для расчета lifetime укажем им дату закрытия как текующую дату
startups_train['closed_at'] = startups_train[
'closed_at'
].fillna('2024-11-02')
# Переведем дату закрытия фирм в формат даты
startups_train['closed_at'] = pd.to_datetime(
    startups_train['closed_at'], format='%Y-%m-%d'
)

# %%
# Создаем параметр lifetime
startups_train['lifetime'] = (
    startups_train['closed_at'] - startups_train['founded_at']
).dt.days
# Проверяем полученный результат
startups_train.head()
# Out:
#                      name                          category_list  \
# 0               Lunchgate        Online Reservations|Restaurants
# 1                 EarLens  Manufacturing|Medical|Medical Devices
# 2  Reviva Pharmaceuticals                          Biotechnology
# 3    Sancilio and Company                            Health Care
# 4     WireTough Cylinders                          Manufacturing
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
# 3         22250000.0  operating          NaN        NaN          NaN
# 4                NaN  operating          USA         VA   VA - Other
#
#            city  funding_rounds founded_at first_funding_at last_funding_at  \
# 0        Zürich               2 2009-10-17       2011-05-01      2014-12-01
# ...

# %%
# Удаляем столбцы с датой основания и закрытия
startups_train = startups_train.drop(
    ['founded_at', 'closed_at'], axis=1
)

# %%
# Сравниваем первичную информацию о тренировочном и тестовом датасетах
startups_train.info()
startups_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   first_funding_at   52516 non-null  object
#  10  last_funding_at    52516 non-null  object
#  11  lifetime           52516 non-null  int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 4.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13125 entries, 0 to 13124
# Data columns (total 12 columns):
# ...

# %% [markdown]
# **Промежуточный вывод:**
# * Судя по первичной информации о датасетах  - имеются пропуски в тренировочных данных и во входных данных тестовой выборки.
# * Наименования столбцов  соответствуют змеинному регистру
# * Все типы колонок соответствуют их содержимому
# * Тренировочный и тестовый датасеты приведны к одинаковому содержанию для моделирования, на основе старых признаком создан в тренировочном датасете создан признак 'lifetime'

# %% [markdown]
# <a id='preprocessing'></a>
# ## [Предобработка данных](#start)

# %%
# Проверим датасет 'startups_train' на наличие явных дубликатов
print(
    'Явных дубликатов в "startups_train" -', 
    startups_train.duplicated().sum()
)
# Out:
# Явных дубликатов в "startups_train" - 0

# %%
# Проверим датасет 'startups_test' на наличие явных дубликатов
print(
    'Явных дубликатов в "startups_train" -', 
    startups_test.duplicated().sum()
)
# Out:
# Явных дубликатов в "startups_train" - 0

# %%
# Проверим датасет 'startups_train' на наличие пропусков
startups_train.isna().sum()
# Out:
# name                     1
# category_list         2465
# funding_total_usd    10069
# status                   0
# country_code          5502
# state_code            6763
# region                6359
# city                  6359
# funding_rounds           0
# first_funding_at         0
# last_funding_at          0
# lifetime                 0
# dtype: int64

# %%
# Создаем объекты для заполнения попусков
# в категориальных колонках по модам
cat_imputer = SimpleImputer(
    missing_values=np.nan, 
    strategy='most_frequent'
)
# в в числовых колонках по медианам
num_imputer = SimpleImputer(
    missing_values=np.nan, 
    strategy='median'
)

# %%
# Создаем список категориальных признаков
cat_col_names = startups_train.select_dtypes(
    exclude='number'
).columns.tolist()
# Смотрим список
cat_col_names
# Out:
# ['name',
#  'category_list',
#  'status',
#  'country_code',
#  'state_code',
#  'region',
#  'city',
#  'first_funding_at',
#  'last_funding_at']

# %%
# Создаем список количественных признаков
num_col_names = startups_train.select_dtypes(
    include='number'
).columns.tolist()
# Смотрим список
num_col_names
# Out:
# ['funding_total_usd', 'funding_rounds', 'lifetime']

# %%
# Обучаем импьютер для категориальных колонок
cat_imputer.fit(startups_train[cat_col_names])
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
# Заполняем пропуски в категориальных колонках
startups_train[cat_imputer.feature_names_in_] = cat_imputer.transform(
    startups_train[cat_col_names]
)

# %%
# Обучаем импьютер для числовых колонок
num_imputer.fit(startups_train[num_col_names])
# Out:
# SimpleImputer(strategy='median')

# %%
# Заполняем пропуски в числовых колонках
startups_train[num_imputer.feature_names_in_] = num_imputer.transform(
    startups_train[num_col_names]
)

# %%
# Проверяем результат
startups_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52516 non-null  object
#  1   category_list      52516 non-null  object
#  2   funding_total_usd  52516 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       52516 non-null  object
#  5   state_code         52516 non-null  object
#  6   region             52516 non-null  object
#  7   city               52516 non-null  object
#  8   funding_rounds     52516 non-null  float64
#  9   first_funding_at   52516 non-null  object
#  10  last_funding_at    52516 non-null  object
#  11  lifetime           52516 non-null  float64
# dtypes: float64(3), object(9)
# memory usage: 4.8+ MB

# %%
# Проверим датасет 'startups_test' на наличие пропусков
startups_test.isna().sum()
# Out:
# name                    0
# category_list         591
# funding_total_usd    2578
# country_code         1382
# state_code           1695
# region               1589
# city                 1587
# funding_rounds          0
# first_funding_at        0
# last_funding_at         0
# lifetime                0
# status                  0
# dtype: int64

# %%
# Заполняем пропуски в категориальных колонках
startups_test[cat_imputer.feature_names_in_] = cat_imputer.transform(
    startups_test[cat_col_names]
)

# %%
# Заполняем пропуски в числовых колонках
startups_test[num_imputer.feature_names_in_] = num_imputer.transform(
    startups_test[num_col_names]
)

# %%
# Проверяем результат
startups_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13125 entries, 0 to 13124
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      13125 non-null  object
#  2   funding_total_usd  13125 non-null  float64
#  3   country_code       13125 non-null  object
#  4   state_code         13125 non-null  object
#  5   region             13125 non-null  object
#  6   city               13125 non-null  object
#  7   funding_rounds     13125 non-null  float64
#  8   first_funding_at   13125 non-null  object
#  9   last_funding_at    13125 non-null  object
#  10  lifetime           13125 non-null  float64
#  11  status             13125 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# **Промежуточный вывод:**
# * Датасеты проверены на наличие явных дубликатов.
# * Обнаруженные пропуски устранены

# %% [markdown]
# <a id='research'></a>
# ## [Исследовательский анализ данных](#start)

# %%
# Строим гистограмму для общего финансирования и boxplot диаграмму, также смотрим описание данных
plt.subplot(1, 2, 1)
startups_train['funding_total_usd'].hist(figsize=(18, 6))
plt.title('Гистограмма общего финансирования')
plt.xlabel('Общее финансирование')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train['funding_total_usd'].plot.box(use_index=False)
plt.ylabel('Общее финансирование')
plt.show()
startups_train['funding_total_usd'].describe()
# Out:
# count    5.251600e+04
# mean     1.513232e+07
# std      1.683466e+08
# min      1.000000e+00
# 25%      5.297212e+05
# 50%      2.000000e+06
# 75%      6.788929e+06
# max      3.007950e+10
# Name: funding_total_usd, dtype: float64

# %%
# Считаем количество компаний с общим финансированием меньше 1000 долларов
print(
    'Количество компаний с общим финансированием меньше 1000 долларов -',
    startups_train['funding_total_usd']
    .loc[startups_train['funding_total_usd'] < 1000]
    .count()
)
# Out:
# Количество компаний с общим финансированием меньше 1000 долларов - 48

# %%
# Считаем количество компаний с общим финансированием больше 10.000.000 долларов
print(
    'Количество компаний с общим финансированием больше 10.000.000 долларов -',
    startups_train['funding_total_usd']
    .loc[startups_train['funding_total_usd'] > 100000000]
    .count()
)
# Out:
# Количество компаний с общим финансированием больше 10.000.000 долларов - 1238

# %%
# Строим гистограмму для общего финансирования и boxplot диаграмму, также смотрим описание данных
plt.subplot(1, 2, 1)
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
].hist(bins=100, figsize=(18, 6))
plt.title('Гистограмма общего финансирования')
plt.xlabel('Общее финансирование')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
].plot.box(use_index=False)
plt.ylabel('Общее финансирование')
plt.show()
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
].describe()
# Out:
# count    5.111400e+04
# mean     7.349213e+06
# std      1.461938e+07
# min      1.050000e+03
# 25%      5.000000e+05
# 50%      2.000000e+06
# 75%      5.844952e+06
# max      9.980000e+07
# Name: funding_total_usd, dtype: float64

# %% [markdown]
# **Распределение финансирования не соответствует нормальному распределению. Большинство стартапов получают низкое финансирование.**

# %%
# Строим диаграмму для количества раундов финансирования и boxplot диаграмму, также смотрим описание данных
plt.subplot(1, 2, 1)
(
    startups_train.groupby('funding_rounds')['funding_rounds']
    .count()
    .plot(kind='bar', legend=False, figsize=(18, 6))
)
plt.title('Диаграмма для количества раундов финансирования')
plt.xlabel('Количество раундов финансирования')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train['funding_rounds'].plot.box(use_index=False)
plt.ylabel('Количество раундов финансирования')
plt.show()
startups_train['funding_rounds'].describe()
# Out:
# count    52516.000000
# mean         1.740670
# std          1.374522
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000
# Name: funding_rounds, dtype: float64

# %% [markdown]
# **Распределение количества раундов финансирования не соответствует нормальному распределению. Большинство стартапов имеют малое количество раундов финансирования. Это коррелирует с низким суммарным финансированием большинства проектов**

# %%
# Строим гистограмму для lifetime стартапов и boxplot диаграмму, также смотрим описание данных
plt.subplot(1, 2, 1)
startups_train['lifetime'].hist(bins=50, figsize=(18, 6))
plt.title('Гистограмма lifetime стартапов')
plt.xlabel('lifetime')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train['lifetime'].plot.box(use_index=False)
plt.ylabel('lifetime')
plt.show()
startups_train['lifetime'].describe()
# Out:
# count    52516.000000
# mean      5404.037493
# std       2440.616197
# min         19.000000
# 25%       4187.000000
# 50%       5013.000000
# 75%       6483.250000
# max      19875.000000
# Name: lifetime, dtype: float64

# %% [markdown]
# **Распределение времени жизни стартапов не соответствует нормальному распределению. Наблюдается бимодальность. Есть пик количества стартапов с временем жизни около 1000 дней.**

# %%
# Cтроим диаграмму количества закрытых и работающих стартапов
(
    startups_train.groupby('status')['funding_rounds']
    .count()
    .plot(kind='bar', legend=False, figsize=(6, 6))
)
plt.title('Диаграмма количества закрытых и открытых стартапов')
plt.xlabel('Статус')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# **Наблюдается сильный дисбаланс классов в целевом признаке**

# %%
# Строим гистограмму для общего финансирования и boxplot диаграмму закрытых стартапов, также смотрим описание данных
plt.subplot(1, 2, 1)
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
    & (startups_train['status'] == 'closed')
].hist(bins=100, figsize=(18, 6))
plt.title('Гистограмма общего финансирования закрытых стартапов')
plt.xlabel('Общее финансирование закрытых стартапов')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
    & (startups_train['status'] == 'closed')
].plot.box(use_index=False)
plt.ylabel('Общее финансирование закрытых стартапов')
plt.show()
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
    & (startups_train['status'] == 'closed')
].describe()
# Out:
# count    4.837000e+03
# mean     5.955917e+06
# std      1.246648e+07
# min      1.100000e+03
# 25%      3.500000e+05
# 50%      2.000000e+06
# 75%      4.500000e+06
# max      9.967000e+07
# Name: funding_total_usd, dtype: float64

# %%
# Строим гистограмму для общего финансирования и boxplot диаграмму работающих стартапов, также смотрим описание данных
plt.subplot(1, 2, 1)
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
    & (startups_train['status'] == 'operating')
].hist(bins=100, figsize=(18, 6))
plt.title('Гистограмма общего финансирования работающих стартапов')
plt.xlabel('Общее финансирование работающих стартапов')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
    & (startups_train['status'] == 'operating')
].plot.box(use_index=False)
plt.ylabel('Общее финансирование работающих стартапов')
plt.show()
startups_train['funding_total_usd'].loc[
    (startups_train['funding_total_usd'] > 1000)
    & (startups_train['funding_total_usd'] < 100000000)
    & (startups_train['status'] == 'operating')
].describe()
# Out:
# count    4.627700e+04
# mean     7.494844e+06
# std      1.481893e+07
# min      1.050000e+03
# 25%      5.250000e+05
# 50%      2.000000e+06
# 75%      6.000000e+06
# max      9.980000e+07
# Name: funding_total_usd, dtype: float64

# %% [markdown]
# **Не наблюдается разницы в гистограммах финансирования закрытых и работающих стартаров**

# %%
# Строим диаграмму для количества раундов финансирования и boxplot диаграмму закрытых стартапов, также смотрим описание данных
plt.subplot(1, 2, 1)
(
    startups_train.loc[startups_train['status'] == 'closed']
    .groupby('funding_rounds')['funding_rounds']
    .count()
    .plot(kind='bar', legend=False, figsize=(18, 6))
)
plt.title('Диаграмма для количества раундов финансирования закрытых стартапов')
plt.xlabel('Количество раундов финансирования закрытых стартапов')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train.loc[startups_train['status'] == 'closed']['funding_rounds'].plot.box(
    use_index=False
)
plt.ylabel('Количество раундов финансирования закрытых стартапов')
plt.show()
startups_train.loc[startups_train['status'] == 'closed']['funding_rounds'].describe()
# Out:
# count    4917.000000
# mean        1.404312
# std         0.962079
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max        11.000000
# Name: funding_rounds, dtype: float64

# %%
# Строим диаграмму для количества раундов финансирования и boxplot диаграмму работающих стартапов, также смотрим описание данных
plt.subplot(1, 2, 1)
(
    startups_train.loc[startups_train['status'] == 'operating']
    .groupby('funding_rounds')['funding_rounds']
    .count()
    .plot(kind='bar', legend=False, figsize=(18, 6))
)
plt.title('Диаграмма для количества раундов финансирования работающих стартапов')
plt.xlabel('Количество раундов финансирования работающих стартапов')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train.loc[startups_train['status'] == 'operating']['funding_rounds'].plot.box(
    use_index=False
)
plt.ylabel('Количество раундов финансирования работающих стартапов')
plt.show()
startups_train.loc[startups_train['status'] == 'operating']['funding_rounds'].describe()
# Out:
# count    47599.000000
# mean         1.775415
# std          1.405699
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000
# Name: funding_rounds, dtype: float64

# %% [markdown]
# **Можно заметить, что все закрытые стартапы имеют не больше 11 раундов финансирования.**

# %%
# Строим гистограмму для lifetime закрытых стартапов и boxplot диаграмму, также смотрим описание данных
plt.subplot(1, 2, 1)
startups_train.loc[startups_train['status'] == 'closed']['lifetime'].hist(
    bins=50, figsize=(18, 6)
)
plt.title('Гистограмма lifetime закрытых стартапов')
plt.xlabel('lifetime')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train.loc[startups_train['status'] == 'closed']['lifetime'].plot.box(
    use_index=False
)
plt.ylabel('lifetime')
plt.show()
startups_train.loc[startups_train['status'] == 'closed']['lifetime'].describe()
# Out:
# count     4917.000000
# mean      1399.249949
# std       1378.294089
# min         19.000000
# 25%        735.000000
# 50%       1013.000000
# 75%       1407.000000
# max      17004.000000
# Name: lifetime, dtype: float64

# %%
# Строим гистограмму для lifetime работающих стартапов и boxplot диаграмму, также смотрим описание данных
plt.subplot(1, 2, 1)
startups_train.loc[startups_train['status'] == 'operating']['lifetime'].hist(
    bins=50, figsize=(18, 6)
)
plt.title('Гистограмма lifetime работающих стартапов')
plt.xlabel('lifetime')
plt.ylabel('Частота')
plt.subplot(1, 2, 2)
startups_train.loc[startups_train['status'] == 'operating']['lifetime'].plot.box(
    use_index=False
)
plt.ylabel('lifetime')
plt.show()
startups_train.loc[startups_train['status'] == 'operating']['lifetime'].describe()
# Out:
# count    47599.000000
# mean      5817.734007
# std       2132.554188
# min       3228.000000
# 25%       4323.000000
# 50%       5076.000000
# 75%       6515.000000
# max      19875.000000
# Name: lifetime, dtype: float64

# %% [markdown]
# **Можно увидеть, что аномальный пик на общей гистограмме lifetime стартапов относится к закрытым стартапам. Пики распределений закрытых и работающих стартапов смещены относительно друг друга.**

# %% [markdown]
# **Промежуточный вывод:**
# * Большинство стартаров имеют низкое финансирование, независимо от того были ли они закрыты или работают
# * Закрытые стартары всегда имеют не больше 11 раундов финансирования
# * На закрытые стартапы приходится отдельный пик в области низкого времени жизни стартапов

# %% [markdown]
# <a id='corr'></a>
# ## [Корреляционный анализ](#start)

# %%
# Строим тепловую карту коэффициентов корреляции Спирмена
fig, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(startups_train.corr(method='spearman'), annot=True, fmt='.2f', ax=ax)
plt.show()

# %% [markdown]
# **В матрице нет признаков с коэффициентом корреляции от 0.9 до 0.95 по модулю.
# Можно сделать вывод об отсутствии мультиколлинеарности.**

# %% [markdown]
# <a id='categories_train'></a>
# ## [Уменьшение числа категориальных признаков в тренировочном датасете](#start)

# %%
# Рассмотрим информацию о параметре 'category_list'
startups_train['category_list'].describe()
# Out:
# count        52516
# unique       22105
# top       Software
# freq          5672
# Name: category_list, dtype: object

# %% [markdown]
# **В датасете 22105 категорий.**

# %%
# Составим список категорий и количество стартапов в них
startups_train.groupby('category_list')['name'].count().sort_values(ascending=False)
# Out:
# category_list
# Software                                                                                       5672
# Biotechnology                                                                                  2905
# E-Commerce                                                                                     1064
# Mobile                                                                                          920
# Clean Technology                                                                                892
#                                                                                                ...
# Business Productivity|Enterprise Application|Mobile|Search|Software|Web Browsers                  1
# Business Productivity|Email|SaaS|Sales and Marketing                                              1
# Business Productivity|EdTech|Enterprise Software|Knowledge Management|Online Education|SaaS       1
# ...

# %%
# Сгруппируем категории с количеством стартапов меньше или равном 100
for categories in startups_train['category_list'].unique():
    count = list(range(1, 101))
    if startups_train['category_list'].loc[startups_train['category_list'] == categories].count() in count:
        startups_train['category_list'] = startups_train['category_list'].replace(
            categories, 'categories with '+ str(
                startups_train['category_list'].loc[startups_train['category_list'] == categories].count()
            ) + ' stratup'
        )

# %%
# Снова составим список категорий и количество стартапов в них
startups_train.groupby('category_list')['name'].count().sort_values(ascending=False)
# Out:
# category_list
# categories with 1 stratup     20140
# Software                       5672
# Biotechnology                  2905
# categories with 2 stratup      2016
# E-Commerce                     1064
#                               ...
# categories with 35 stratup       35
# categories with 30 stratup       30
# categories with 24 stratup       24
# categories with 23 stratup       23
# categories with 22 stratup       22
# Name: name, Length: 97, dtype: int64

# %% [markdown]
# **Теперь в датасете 97 категорий.**

# %%
# Построим диаграмму количества стартпов в разных категориях
startups_train.groupby(
    'category_list'
)['name'].count().sort_values(
    ascending=False
).plot(kind='bar', figsize=(18, 6))
plt.show()

# %%
# Рассмотрим информацию о параметре 'country_code'
startups_train['country_code'].describe()
# Out:
# count     52516
# unique      134
# top         USA
# freq      35204
# Name: country_code, dtype: object

# %% [markdown]
# **В датасете 134 страны**

# %%
# Составим список стран и количество стартапов в них
startups_train.groupby('country_code')['name'].count().sort_values(ascending=False)
# Out:
# country_code
# USA    35204
# GBR     2925
# CAN     1540
# IND     1276
# CHN     1240
#        ...
# MNE        1
# NIC        1
# QAT        1
# PSE        1
# JEY        1
# Name: name, Length: 134, dtype: int64

# %%
# Сгруппируем страны с количеством стартапов меньше или равном 100
for countries in startups_train['country_code'].unique():
    count = list(range(1, 101))
    if startups_train['country_code'].loc[startups_train['country_code'] == countries].count() in count:
        startups_train['country_code'] = startups_train['country_code'].replace(
            countries, 'countries with '+ str(
                startups_train['country_code'].loc[startups_train['country_code'] == countries].count()
            ) + ' stratup'
        )

# %%
# Снова составим список стран и количество стартапов в них
startups_train.groupby('country_code')['name'].count().sort_values(ascending=False)
# Out:
# country_code
# USA                          35204
# GBR                           2925
# CAN                           1540
# IND                           1276
# CHN                           1240
#                              ...
# countries with 19 stratup       19
# countries with 6 stratup        18
# countries with 15 stratup       15
# countries with 12 stratup       12
# countries with 4 stratup         8
# Name: name, Length: 65, dtype: int64

# %%
# Построим диаграмму количества стартпов в разных странах
startups_train.groupby(
    'country_code'
)['name'].count().sort_values(
    ascending=False
).plot(kind='bar', figsize=(18, 6))
plt.show()

# %%
# Рассмотрим информацию о параметре 'city'
startups_train['city'].describe()
# Out:
# count             52516
# unique             4477
# top       San Francisco
# freq               9183
# Name: city, dtype: object

# %% [markdown]
# **В датасете 4477 городов**

# %%
# Составим список городов и количество стартапов в них
startups_train.groupby('city')['name'].count().sort_values(ascending=False)
# Out:
# city
# San Francisco    9183
# New York         2486
# London           1514
# Austin            609
# Palo Alto         607
#                  ...
# Mohali              1
# Moirans             1
# Mombasa             1
# Monaca              1
# Örnsköldsvik        1
# Name: name, Length: 4477, dtype: int64

# %%
# Сгруппируем города с количеством стартапов меньше или равном 100
for cities in startups_train['city'].unique():
    count = list(range(1, 101))
    if startups_train['city'].loc[startups_train['city'] == cities].count() in count:
        startups_train['city'] = startups_train['city'].replace(
            cities, 'cities with '+ str(
                startups_train['city'].loc[startups_train['city'] == cities].count()
            ) + ' stratup'
        )

# %%
# Снова составим список городов и количество стартапов в них
startups_train.groupby('city')['name'].count().sort_values(ascending=False)
# Out:
# city
# San Francisco             9183
# New York                  2486
# cities with 1 stratup     2304
# London                    1514
# cities with 2 stratup     1404
#                           ...
# cities with 54 stratup      54
# cities with 52 stratup      52
# cities with 49 stratup      49
# cities with 48 stratup      48
# cities with 47 stratup      47
# Name: name, Length: 157, dtype: int64

# %%
# Построим диаграмму количества стартпов в разных городах
startups_train.groupby(
    'city'
)['name'].count().sort_values(
    ascending=False
).plot(kind='bar', figsize=(27, 6))
plt.show()

# %%
# Рассмотрим информацию о параметре 'region'
startups_train['region'].describe()
# Out:
# count           52516
# unique           1036
# top       SF Bay Area
# freq            13329
# Name: region, dtype: object

# %% [markdown]
# **В датасете 1036 регионов**

# %%
# Составим список регионов и количество стартапов в них
startups_train.groupby('region')['name'].count().sort_values(ascending=False)
# Out:
# region
# SF Bay Area       13329
# New York City      2776
# Boston             1890
# London             1840
# Los Angeles        1513
#                   ...
# Royston               1
# Herzogenaurach        1
# NH - Other            1
# Surbiton              1
# Levis                 1
# Name: name, Length: 1036, dtype: int64

# %%
# Сгруппируем регионы с количеством стартапов меньше или равном 100
for regions in startups_train['region'].unique():
    count = list(range(1, 101))
    if startups_train['region'].loc[startups_train['region'] == regions].count() in count:
        startups_train['region'] = startups_train['region'].replace(
            regions, 'regions with '+ str(
                startups_train['region'].loc[startups_train['region'] == regions].count()
            ) + ' stratup'
        )

# %%
# Снова составим список регионов и количество стартапов в них
startups_train.groupby('region')['name'].count().sort_values(ascending=False)
# Out:
# region
# SF Bay Area                13329
# New York City               2776
# Boston                      1890
# London                      1840
# Los Angeles                 1513
#                            ...
# regions with 23 stratup       46
# regions with 45 stratup       45
# regions with 43 stratup       43
# regions with 40 stratup       40
# regions with 39 stratup       39
# Name: name, Length: 154, dtype: int64

# %%
# Построим диаграмму количества стартапов в разных регионах
startups_train.groupby(
    'region'
)['name'].count().sort_values(
    ascending=False
).plot(kind='bar', figsize=(27, 6))
plt.show()

# %%
# Рассмотрим информацию о параметре 'state_code'
startups_train['state_code'].describe()
# Out:
# count     52516
# unique      300
# top          CA
# freq      16982
# Name: state_code, dtype: object

# %% [markdown]
# **В датасете 300 кодов штатов**

# %%
# Составим список кодов штатов и количество стартапов в них
startups_train.groupby('state_code')['name'].count().sort_values(ascending=False)
# Out:
# state_code
# CA    16982
# NY     3112
# MA     2020
# TX     1562
# H9     1510
#       ...
# PE        1
# Q6        1
# T7        1
# T8        1
# Z8        1
# Name: name, Length: 300, dtype: int64

# %%
# Сгруппируем коды штатов с количеством стартапов меньше или равном 100
for states in startups_train['state_code'].unique():
    count = list(range(1, 101))
    if startups_train['state_code'].loc[startups_train['state_code'] == states].count() in count:
        startups_train['state_code'] = startups_train['state_code'].replace(
            states, 'states with '+ str(
                startups_train['state_code'].loc[startups_train['state_code'] == states].count()
            ) + ' stratup'
        )

# %%
# Снова составим список кодов штатов и количество стартапов в них
startups_train.groupby('state_code')['name'].count().sort_values(ascending=False)
# Out:
# state_code
# CA                        16982
# NY                         3112
# MA                         2020
# TX                         1562
# H9                         1510
#                           ...
# states with 12 stratup       36
# states with 8 stratup        32
# states with 26 stratup       26
# states with 23 stratup       23
# states with 16 stratup       16
# Name: name, Length: 122, dtype: int64

# %%
# Построим диаграмму количества стартапов в разных штатах
startups_train.groupby(
    'state_code'
)['name'].count().sort_values(
    ascending=False
).plot(kind='bar', figsize=(27, 6))
plt.show()

# %%
# Рассмотрим информацию о параметре 'first_funding_at'
startups_train['first_funding_at'].describe()
# Out:
# count          52516
# unique          4603
# top       2013-01-01
# freq             450
# Name: first_funding_at, dtype: object

# %%
# Составим список дат первого финансирования
startups_train['first_funding_at'].sort_values(ascending=False)
# Out:
# 19699    2015-12-05
# 49547    2015-12-04
# 25443    2015-12-04
# 1247     2015-12-04
# 30904    2015-12-04
#             ...
# 19862    1983-06-01
# 5878     1982-12-01
# 25018    1982-03-20
# 26761    1979-01-01
# 8904     1977-05-15
# Name: first_funding_at, Length: 52516, dtype: object

# %%
# Переведем дату первого финансирования фирм в формат даты
startups_train['first_funding_at'] = pd.to_datetime(
    startups_train['first_funding_at'], format='%Y-%m-%d'
)

# %%
# Оставим только год первого финансирования в формате строки
startups_train['first_funding_at'] = startups_train['first_funding_at'].dt.year.astype('str')

# %%
# Снова рассмотрим информацию о параметре 'first_funding_at'
startups_train['first_funding_at'].describe()
# Out:
# count     52516
# unique       36
# top        2014
# freq       9348
# Name: first_funding_at, dtype: object

# %%
# Построим диаграмму количества стартапов получивших первое финансирование в разные годы
startups_train.groupby(
    'first_funding_at'
)['name'].count().plot(kind='bar', figsize=(18, 6))
plt.show()

# %%
# Рассмотрим информацию о параметре 'last_funding_at'
startups_train['last_funding_at'].describe()
# Out:
# count          52516
# unique          4305
# top       2014-01-01
# freq             369
# Name: last_funding_at, dtype: object

# %%
# Составим список дат последнего финансирования
startups_train['last_funding_at'].sort_values(ascending=False)
# Out:
# 51073    2015-12-07
# 19699    2015-12-05
# 52323    2015-12-04
# 30904    2015-12-04
# 47577    2015-12-04
#             ...
# 19862    1983-06-01
# 5878     1982-12-01
# 25018    1982-03-20
# 26761    1979-01-01
# 8904     1977-05-15
# Name: last_funding_at, Length: 52516, dtype: object

# %%
# Переведем дату последнего финансирования фирм в формат даты
startups_train['last_funding_at'] = pd.to_datetime(
    startups_train['last_funding_at'], format='%Y-%m-%d'
)

# %%
# Оставим только год первого финансирования в формате строки
startups_train['last_funding_at'] = startups_train['last_funding_at'].dt.year.astype('str')

# %%
# Снова рассмотрим информацию о параметре 'last_funding_at'
startups_train['last_funding_at'].describe()
# Out:
# count     52516
# unique       36
# top        2015
# freq      11734
# Name: last_funding_at, dtype: object

# %%
# Построим диаграмму количества стартапов получивших первое финансирование в разные годы
startups_train.groupby(
    'last_funding_at'
)['name'].count().plot(kind='bar', figsize=(18, 6))
plt.show()

# %% [markdown]
# <a id='categories_test'></a>
# ## [Уменьшение числа категориальных признаков в тестовом датасете](#start)

# %%
# Изначально в тестовом датасете
print(startups_test['category_list'].nunique(), 'категориальных признаков')
print(startups_test['country_code'].nunique(), 'стран')
print(startups_test['state_code'].nunique(), 'кодов штатов')
print(startups_test['region'].nunique(), 'регионов')
print(startups_test['city'].nunique(), 'городов')
print(startups_test['first_funding_at'].nunique(), 'даты первого финансирования')
print(startups_test['last_funding_at'].nunique(), 'даты последнего финансирования')
# Out:
# 6206 категориальных признаков
# 96 стран
# 235 кодов штатов
# 688 регионов
# 2117 городов
# 3299 даты первого финансирования
# 3021 даты последнего финансирования

# %%
# Сгруппируем категории с количеством стартапов меньше или равном 100
for categories in startups_test['category_list'].unique():
    count = list(range(1, 101))
    if startups_test['category_list'].loc[startups_test['category_list'] == categories].count() in count:
        startups_test['category_list'] = startups_test['category_list'].replace(
            categories, 'categories with '+ str(
                startups_test['category_list'].loc[startups_test['category_list'] == categories].count()
            ) + ' stratup'
        )

# %%
# Сгруппируем страны с количеством стартапов меньше или равном 100
for countries in startups_test['country_code'].unique():
    count = list(range(1, 101))
    if startups_test['country_code'].loc[startups_test['country_code'] == countries].count() in count:
        startups_test['country_code'] = startups_test['country_code'].replace(
            countries, 'countries with '+ str(
                startups_test['country_code'].loc[startups_test['country_code'] == countries].count()
            ) + ' stratup'
        )

# %%
# Сгруппируем коды штатов с количеством стартапов меньше или равном 100
for states in startups_test['state_code'].unique():
    count = list(range(1, 101))
    if startups_test['state_code'].loc[startups_test['state_code'] == states].count() in count:
        startups_test['state_code'] = startups_test['state_code'].replace(
            states, 'states with '+ str(
                startups_test['state_code'].loc[startups_test['state_code'] == states].count()
            ) + ' stratup'
        )

# %%
# Сгруппируем регионы с количеством стартапов меньше или равном 100
for regions in startups_test['region'].unique():
    count = list(range(1, 101))
    if startups_test['region'].loc[startups_test['region'] == regions].count() in count:
        startups_test['region'] = startups_test['region'].replace(
            regions, 'regions with '+ str(
                startups_test['region'].loc[startups_test['region'] == regions].count()
            ) + ' stratup'
        )

# %%
# Сгруппируем города с количеством стартапов меньше или равном 100
for cities in startups_test['city'].unique():
    count = list(range(1, 101))
    if startups_test['city'].loc[startups_test['city'] == cities].count() in count:
        startups_test['city'] = startups_test['city'].replace(
            cities, 'cities with '+ str(
                startups_test['city'].loc[startups_test['city'] == cities].count()
            ) + ' stratup'
        )

# %%
# Переведем дату первого финансирования фирм в формат даты
startups_test['first_funding_at'] = pd.to_datetime(
    startups_test['first_funding_at'], format='%Y-%m-%d'
)
# Оставим только год первого финансирования в формате строки
startups_test['first_funding_at'] = startups_test['first_funding_at'].dt.year.astype('str')

# %%
# Переведем дату последнего финансирования фирм в формат даты
startups_test['last_funding_at'] = pd.to_datetime(
    startups_test['last_funding_at'], format='%Y-%m-%d'
)
# Оставим только год первого финансирования в формате строки
startups_test['last_funding_at'] = startups_test['last_funding_at'].dt.year.astype('str')

# %%
# После в тестовом датасете
print(startups_test['category_list'].nunique(), 'категориальных признаков')
print(startups_test['country_code'].nunique(), 'стран')
print(startups_test['state_code'].nunique(), 'кодов штатов')
print(startups_test['region'].nunique(), 'регионов')
print(startups_test['city'].nunique(), 'городов')
print(startups_test['first_funding_at'].nunique(), 'даты первого финансирования')
print(startups_test['last_funding_at'].nunique(), 'даты последнего финансирования')
# Out:
# 59 категориальных признаков
# 50 стран
# 82 кодов штатов
# 83 регионов
# 78 городов
# 33 даты первого финансирования
# 33 даты последнего финансирования

# %% [markdown]
# <a id='models'></a>
# ## [Разработка моделей](#start)

# %%
# Разделим датасет на датасеты с входными и целевым признаком
X_train = startups_train.drop(['name', 'status'], axis=1)
y_train = startups_train['status']
X_test = startups_test.drop(['name', 'status'], axis=1)
y_test = startups_test['status']
# Создаем список категориальных признаков
cat_col_names = X_train.select_dtypes(exclude='number').columns.tolist()
# Подготовим список категорий для ord-кодирования
categories = [
    X_train[cat_col_names[0]].unique(), 
    X_train[cat_col_names[1]].unique(),
    X_train[cat_col_names[2]].unique(), 
    X_train[cat_col_names[3]].unique(),
    X_train[cat_col_names[4]].unique(), 
    X_train[cat_col_names[5]].unique(),
    X_train[cat_col_names[6]].unique()
]
# Создаем список количественных признаков
num_col_names = X_train.select_dtypes(include='number').columns.tolist()
